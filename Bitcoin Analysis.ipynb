# %% [markdown]
# ## Bitcoin Analysis

# %% [markdown]
# Code to download Bitcoin Data from https://coinmarketcap.com/

# %%
from cryptocmd import CmcScraper

# initialise scraper with time interval
scraper = CmcScraper("BTC", "01-01-2018", "10-03-2021")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
json_data = scraper.get_data("json")

# get dataframe for the data
df = scraper.get_dataframe()
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2021-03-10  54824.011199  57258.254976  53290.891169  56008.549401
# 1    2021-03-09  52272.969782  54824.117811  51981.831312  54824.117811
# 2    2021-03-08  51174.116947  52314.068801  49506.053458  52246.522310
# 3    2021-03-07  48918.680265  51384.366010  48918.680265  51206.692953
# 4    2021-03-06  48899.230782  49147.218220  47257.526908  48912.381731
# ...         ...           ...           ...           ...           ...
# 1160 2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# 1161 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 1162 2018-01-03  14978.200195  15572.799805  14844.500000  15201.000000
# 1163 2018-01-02  13625.000000  15444.599609  13163.599609  14982.099609
# 1164 2018-01-01  14112.200195  14112.200195  13154.700195  13657.200195
#
#             Volume    Market Cap
# 0     5.729558e+10  1.044580e+12
# 1     5.091223e+10  1.022440e+12
# ...

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.update_layout(
    title='Candlestick chart for BTC',
    yaxis_title='Bitcoin Price')


fig.show()
# Out:
# <div>                            <div id="1713be4b-2afe-418a-8b45-738910b07be9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1713be4b-2afe-418a-8b45-738910b07be9")) {                    Plotly.newPlot(                        "1713be4b-2afe-418a-8b45-738910b07be9",                        [{"close": [56008.54940114, 54824.11781138, 52246.52230995, 51206.69295308, 48912.38173056, 48927.3045548, 48561.1661539, 50538.24341445, 48378.98805435, 49631.24137077, 45137.77046805, 46188.45127539, 46339.76008289, 47093.85301914, 49705.33331637, 48824.42686909, 54207.31906543, 57539.9436679, 56099.52051348, 55888.13368221, 51679.79669449, 52149.00753587, 49199.87134362, 47945.05683234, 48717.2902111, 47105.51747252, 47504.85118326, 47909.33119483, 44918.184491
# ...

# %%
import plotly.graph_objects as go


from pandas_datareader import data as pdr

# Create figure
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(df.Date), y=list(df.Close)))

# Set title
fig.update_layout(
    title_text="Bitcoin Data Trend"
)

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="c0825f22-eaf5-4554-8cd9-2d91fb783d3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0825f22-eaf5-4554-8cd9-2d91fb783d3a")) {                    Plotly.newPlot(                        "c0825f22-eaf5-4554-8cd9-2d91fb783d3a",                        [{"type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-07T00:00:00", "2021-03-06T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-28T00:00:00", "2021-02-27T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-21T00:00:00", "2021-02-20T00:00:00", "202
# ...
